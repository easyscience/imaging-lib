# %%
from easyimaging import Measurement

# %%
measurement = Measurement.from_scitiff('../small_scitiff.tiff')

# %%
measurement.rebin({'x':5})

# %%
measurement.revert_rebin()

# %%
measurement.plot()
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\ipympl\backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# ...

# %%
# %matplotlib widget

# %%
measurement.slider_plot()
# Out:
# InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(icon='home', la…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\ipympl\backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# --> 474     self.canvas.handle_event(content)
#
# ...

# %%
measurement.spectrum_inspector()
# Out:
# c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\matplotlib\colors.py:778: RuntimeWarning: overflow encountered in multiply
#   xa *= self.N
# Box(children=(InteractiveFigure(children=(HBar(), HBar(children=(VBar(children=(Toolbar(children=(ButtonTool(i…
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\ipympl\backend_nbagg.py:289, in Canvas._handle_message(self, object, content, buffers)
#     286     self.manager.handle_json(content)
#     288 else:
# --> 289     self.manager.handle_json(content)
#
# File c:\Users\christianvedel\EasyScienceSource\imaging-lib\.pixi\envs\dev\Lib\site-packages\matplotlib\backends\backend_webagg_core.py:474, in FigureManagerWebAgg.handle_json(self, content)
#     473 def handle_json(self, content):
# ...

# %%
test = measurement._data_array

# %%
import plopp as pp

# %%
# %matplotlib widget

# %%
import matplotlib

# %%
matplotlib.get_backend()

# %%
import scipp as sc
import numpy as np
import plopp as pp

# %%
tof = sc.arange('t', 0, 10, 1, unit='s')
x = sc.arange('x', 0, 7, 1, unit='m')
y = sc.arange('y', 0, 7, 1, unit='m')
data = sc.array(dims=['x', 'y', 't'], values=np.random.rand(6,6,10))

test = sc.DataArray(data=data, coords={'tof': tof, 'x': x, 'y': y})

# %%
# %matplotlib widget

# %%
pp.inspector(test, dim='t', ymax=4, ymin=1)
